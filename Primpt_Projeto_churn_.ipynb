# %%
def criar_prompt_marketing_telecom(dados_cliente):
    return f"""
Aja como um Analista de Marketing Sênior especializado em Retenção de Clientes
no setor de Telecomunicações. Sua missão é gerar relatórios estratégicos, claros
e profissionais, usando exclusivamente os dados abaixo.


Dados do Cliente
- Estado: {dados_cliente.get('State', 'N/A')}
- Tempo de Conta (meses): {dados_cliente.get('Account length', 'N/A')}
- Código de Área: {dados_cliente.get('Area code', 'N/A')}
- Plano Internacional: {dados_cliente.get('International plan', 'N/A')}
- Caixa Postal (Voice Mail): {dados_cliente.get('Voice mail plan', 'N/A')}
- Número de Mensagens de Voz: {dados_cliente.get('Number vmail messages', 'N/A')}

Uso – Período Diurno
- Minutos: {dados_cliente.get('Total day minutes', 'N/A')}
- Chamadas: {dados_cliente.get('Total day calls', 'N/A')}
- Custo: {dados_cliente.get('Total day charge', 'N/A')}

Uso – Período da Tarde
- Minutos: {dados_cliente.get('Total eve minutes', 'N/A')}
- Chamadas: {dados_cliente.get('Total eve calls', 'N/A')}
- Custo: {dados_cliente.get('Total eve charge', 'N/A')}

Uso – Período Noturno
- Minutos: {dados_cliente.get('Total night minutes', 'N/A')}
- Chamadas: {dados_cliente.get('Total night calls', 'N/A')}
- Custo: {dados_cliente.get('Total night charge', 'N/A')}

Uso – Ligações Internacionais
- Minutos: {dados_cliente.get('Total intl minutes', 'N/A')}
- Chamadas: {dados_cliente.get('Total intl calls', 'N/A')}
- Custo: {dados_cliente.get('Total intl charge', 'N/A')}

Relacionamento com Suporte
- Chamadas ao Suporte: {dados_cliente.get('Customer service calls', 'N/A')}

Cancelamento (Churn)
- Status: {dados_cliente.get('Churn', 'N/A')}


Com base exclusivamente nesses dados, gere um relatório estruturado em 3 seções:


1. Resumo do Perfil do Cliente
Descreva o comportamento geral considerando:
- padrão de uso (diurno, tarde, noturno, internacional),
- adoção de planos especiais (voz, internacional),
- nível de contato com suporte,
- sinais potenciais de frustração ou satisfação.


2. Avaliação de Risco de Cancelamento
Explique:
- risco: alto, médio ou baixo (justifique com dados),
- quais variáveis mais influenciam esse risco,
- destaque padrões relevantes (ex.: alto uso internacional, uso diurno elevado, muitas ligações ao suporte).


3. Recomendações de Ação para Marketing
Indique pelo menos 3 ações práticas, como:
- ofertas específicas personalizadas,
- upgrades de plano alinhados ao padrão de uso,
- ações de retenção segmentadas,
- redução de atritos operacionais,
- comunicação direcionada (ex.: campanhas educativas ou preventivas),
- qualquer outra recomendação estratégica baseada nos dados.

O relatório final deve ser:
- profissional, objetivo e claro,
- adequado para apresentação à gerência,
- e gerado em formato PDF.
"""
